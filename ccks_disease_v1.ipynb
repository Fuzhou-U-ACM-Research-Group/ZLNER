# %%
os.environ['CUDA_VISIBLE_DEVICES']='1'
from CC.trainer import NERTrainer

args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/ccks_pre_4/Bert_19215/pytorch_model.bin',
    'hidden_dim': 300,
    'max_seq_length': 128,
    'max_scan_num': 1000000,
    'inter_max_scan_num': 39000,
    'train_file': './data/ccks/train_1000.json',
    'eval_file': './data/ccks/test.json',
    'test_file': './data/ccks/test.json',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/labels.txt',
    'loader_name': 'le_loader_zl',
    'output_eval':True,
    "word_embedding_file":"./data/tencent/word_embedding.txt",
    "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "inter_knowledge_file":"./data/tencent/disease.dic",
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'ZLEBert',
    'classify':'lstm_crf',
    'task_name': 'ccks_v1_disease_1'
}

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i

# %%
os.environ['CUDA_VISIBLE_DEVICES']='1'
from CC.trainer import NERTrainer

args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/ccks_pre_4/Bert_19215/pytorch_model.bin',
    'hidden_dim': 300,
    'max_seq_length': 128,
    'max_scan_num': 1000000,
    'inter_max_scan_num': 39000,
    'train_file': './data/ccks/train_750.json',
    'eval_file': './data/ccks/test.json',
    'test_file': './data/ccks/test.json',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/labels.txt',
    'loader_name': 'le_loader_zl',
    'output_eval':True,
    "word_embedding_file":"./data/tencent/word_embedding.txt",
    "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "inter_knowledge_file":"./data/tencent/disease.dic",
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'ZLEBert',
    'classify':'lstm_crf',
    'task_name': 'ccks_v1_disease_750_1'
}

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_750_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_750_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_750_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_disease_750_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i
# Out:
# kwargs parser: {
#     "batch_size": 8,
#     "eval_batch_size": 64,
#     "test_batch_size": 16,
#     "word_embedding_file": "./data/tencent/word_embedding.txt",
#     "word_vocab_file": "./data/tencent/tencent_vocab.txt",
#     "train_file": "./data/ccks/train_750.json",
#     "eval_file": "./data/ccks/test.json",
#     "test_file": "./data/ccks/test.json",
#     "tag_file": "data/ccks/labels.txt",
#     "inter_knowledge_file": "./data/tencent/disease.dic",
#     "bert_vocab_file": "./model/chinese_wwm_ext/vocab.txt",
#     "output_eval": true,
#     "max_scan_num": 1000000,
#     "inter_max_scan_num": 39000,
#     "add_seq_vocab": false,
#     "max_seq_length": 128,
#     "max_word_num": 5,
#     "default_tag": "O",
#     "use_test": false,
#     "do_shuffle": true,
#     "do_predict": false,
#     "task_name": "ccks_v1_disease_750_1"
# }
# calculate ./data/ccks/train_750.json etag: 100%|██████████| 3.69M/3.69M [00:00<00:00, 331MB/s]
# ...
